# %%
import json 
import pandas as pd

# %%
cols = ["price", "size_and_rooms", "location"]

import re

def read(path: str) -> pd.DataFrame:
    data = []
    with open(path, "r", encoding="utf8") as file:
        for line in file:
            data.append(json.loads(line))

    return pd.DataFrame.from_records(data)


def _room_and_size(s, index=0, sep1=",", sep2=" "):
    if s is None:
        return 
    
    try:
        return int(s.strip().split(sep1)[index].strip().split(sep2)[0])
    except IndexError:
        return
    
def _price(p):
    num_p = re.sub(r'\D', '', p.replace("DH", "").replace("\xa0", ""))
    if not num_p:
        return 
    return int(num_p)
    

def pre_process(data: pd.DataFrame) -> pd.DataFrame:
    data.price = data.price.apply(_price)
    data["rooms"] = data.size_and_rooms.apply(lambda x: _room_and_size(x))
    data["surface"] = data.size_and_rooms.apply(lambda x: _room_and_size(x, index=1))
    data["city"] = data.location.apply(lambda x: x.split("à")[-1])
    data["district"] = data.location.apply(lambda x: x.split("à")[0])
    data.title = data.title.str.lower().str.strip()
    data.city = data.city.str.lower().str.strip()
    data.district = data.district.str.lower().str.strip()

    data.drop(columns=["location", "size_and_rooms", "images"], inplace=True)
    return data

# %%
df = read("data/immo_data.json")

# %%
df.head()
# Out:
#                                                 link property_id
# 0  https://www.mubawab.ma/fr/pa/6777728/apparteme...     6777728  \
# 1  https://www.mubawab.ma/fr/pa/7157727/apparteme...     7157727
# 2  https://www.mubawab.ma/fr/pa/7459735/apparteme...     7459735
# 3  https://www.mubawab.ma/fr/pa/7623664/apparteme...     7623664
# 4  https://www.mubawab.ma/fr/pa/7480730/apparteme...     7480730
#
#           price                                         title
# 0    250 000 DH  Appartement de 59m² en vente, Ahl Loghlam...  \
# 1  1 544 000 DH  Appartement de 78m² en vente Résidence Di...
# 2  1 470 000 DH  Appartement de 122m² en vente avec en plu...
# 3    710 000 DH  Appartement 81m² en vente, Résidence Al B...
# 4  1 498 000 DH   Appartement au RDC de 100m² en vente Les...
#
#        size_and_rooms                                location
# 0   2 chambres, 59 m²  Ahl Loghlam (Hay Assalam) à Casablanca  \
# 1   2 chambres, 78 m²           Maârif Extension à Casablanca
# 2  3 chambres, 122 m²                  Belvédère à Casablanca
# 3   2 chambres, 81 m²                   Al Azhar à Casablanca
# 4  3 chambres, 100 m²                 Californie à Casablanca
#
#                                          description
# 0  c’est au cœur de la ville nouvelle de tit mell...  \
# 1  idéal pour les investisseurs ou les jeunes act...
# 2  chraibi immobilier est un projet résidentiel c...
# 3  le complexe résidentiel al-badr propose des ap...
# 4  composée de 4 immeubles en r4, les allées de c...
#
#                                               images
# 0  [https://www.mubawab-media.com/ad/6/777/728F/m...
# 1  [https://www.mubawab-media.com/ad/7/157/727F/m...
# 2  [https://www.mubawab-media.com/ad/7/459/735F/m...
# 3  [https://www.mubawab-media.com/ad/7/623/664F/m...
# 4  [https://www.mubawab-media.com/ad/7/480/730F/m...

# %%
len(df)
# Out:
# 7173

# %%
data = pre_process(df)

# %%
data
# Out:
#                                                    link property_id
# 0     https://www.mubawab.ma/fr/pa/6777728/apparteme...     6777728  \
# 1     https://www.mubawab.ma/fr/pa/7157727/apparteme...     7157727
# 2     https://www.mubawab.ma/fr/pa/7459735/apparteme...     7459735
# 3     https://www.mubawab.ma/fr/pa/7623664/apparteme...     7623664
# 4     https://www.mubawab.ma/fr/pa/7480730/apparteme...     7480730
# ...                                                 ...         ...
# 7168  https://www.mubawab.ma/fr/a/7546868/vente-bel-...     7546868
# 7169  https://www.mubawab.ma/fr/a/7503990/appartemen...     7503990
# 7170  https://www.mubawab.ma/fr/a/7407371/vend-appar...     7407371
# 7171  https://www.mubawab.ma/fr/pa/7597957/apparteme...     7597957
# 7172  https://www.mubawab.ma/fr/a/7712810/appartemen...     7712810
#
#           price                                         title
# 0      250000.0  appartement de 59m² en vente, ahl loghlam...  \
# 1     1544000.0  appartement de 78m² en vente résidence di...
# 2     1470000.0  appartement de 122m² en vente avec en plu...
# 3      710000.0  appartement 81m² en vente, résidence al b...
# 4     1498000.0   appartement au rdc de 100m² en vente les...
# ...         ...                                           ...
# 7168  1600000.0              vente bel appartement princesses
# 7169  1060000.0  appartement de 184m dont 25 terrasse bélv...
# 7170  1300000.0  vend appartement à ain chock. 2 pièces. c...
# 7171  3300000.0       appartement à vendre. surface de 134 m²
# 7172  3265000.0         appartement à vendre galeria gauthier
#
#                                             description  rooms  surface
# 0     c’est au cœur de la ville nouvelle de tit mell...    2.0     59.0  \
# 1     idéal pour les investisseurs ou les jeunes act...    2.0     78.0
# 2     chraibi immobilier est un projet résidentiel c...    3.0    122.0
# 3     le complexe résidentiel al-badr propose des ap...    2.0     81.0
# 4     composée de 4 immeubles en r4, les allées de c...    3.0    100.0
# ...                                                 ...    ...      ...
# 7168  idéalement situé dans le très apprécié quartie...    NaN      NaN
# 7169  particulier met en vente un appartement situé ...    NaN      NaN
# 7170  découvrez cet appartement à vendre. prix 1 300...    NaN      NaN
# 7171  laissez-vous tenter par la vie dont vous en av...    NaN      NaN
# 7172  découvrez cet appartement à vendre. prix 3 265...    NaN      NaN
#
#             city                   district
# 0     casablanca  ahl loghlam (hay assalam)
# 1     casablanca           maârif extension
# 2     casablanca                  belvédère
# 3     casablanca                   al azhar
# 4     casablanca                 californie
# ...          ...                        ...
# 7168  casablanca             les princesses
# 7169  casablanca                  belvédère
# 7170  casablanca                  ain chock
# 7171  casablanca                     racine
# 7172  casablanca                   gauthier
#
# [7173 rows x 9 columns]

# %%
data.district.value_counts().sort_values()
# Out:
# district
# bouchentouf          1
# michouar             1
# jamila 3             1
# derb douam           1
# les crêtes           1
#                   ...
# bourgogne ouest    284
# aïn sebaâ          290
# racine             310
# maârif             313
# oulfa              459
# Name: count, Length: 182, dtype: int64

# %%
data[data['district'] == 'oulfa'].surface.describe()
# Out:
# count     14.000000
# mean      75.428571
# std       39.570219
# min       40.000000
# 25%       54.250000
# 50%       57.000000
# 75%       82.250000
# max      184.000000
# Name: surface, dtype: float64

# %%
data_dict = data.to_dict('records')

# %%
data_dict
# Out:
# [{'link': 'https://www.mubawab.ma/fr/pa/6777728/appartement-de-59m%C2%B2-en-vente-ahl-loghlam-social-tit-mellil',
#   'property_id': '6777728',
#   'price': 250000.0,
#   'title': 'appartement de 59m² en vente, ahl loghlam...',
#   'description': 'c’est au cœur de la ville nouvelle de tit mellil, à 2mins seulement de l’autoroute périphérique et 20mins seulement de l’aéroport mohamed v, que shem’s al madina vous fait découvrir sa nouvelle résidence « ... En savoir plus',
#   'rooms': 2.0,
#   'surface': 59.0,
#   'city': 'casablanca',
#   'district': 'ahl loghlam (hay assalam)'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7157727/appartement-de-78m%C2%B2-en-vente-r%C3%A9sidence-diaz',
#   'property_id': '7157727',
#   'price': 1544000.0,
#   'title': 'appartement de 78m² en vente résidence di...',
#   'description': 'idéal pour les investisseurs ou les jeunes actifs à la recherche d’une acquisition, la résidence diaz, est un projet qui concilie entre centre-ville et calme inouï. avant-gardisme et confort , ... En savoir plus',
#   'rooms': 2.0,
#   'surface': 78.0,
#   'city': 'casablanca',
#   'district': 'maârif extension'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7459735/appartement-de-122m%C2%B2-en-vente-avec-en-plus-place-parking-titr%C3%A9e-de-15-m%C2%B2-chraibi-immobilier',
#   'property_id': '7459735',
#   'price': 1470000.0,
#   'title': 'appartement de 122m² en vente avec en plu...',
#   'description': 'chraibi immobilier est un projet résidentiel composé de six immeubles situé au cœur de casablanca dans le quartier belevedere-gironde. le projet repose sur un concept fort autour de trois éléments ... En savoir plus',
#   'rooms': 3.0,
#   'surface': 122.0,
#   'city': 'casablanca',
#   'district': 'belvédère'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7623664/appartement-81m%C2%B2-en-vente-r%C3%A9sidence-al-badr',
#   'property_id': '7623664',
#   'price': 710000.0,
#   'title': 'appartement 81m² en vente, résidence al b...',
#   'description': "le complexe résidentiel al-badr propose des appartements de haute qualité. ses superficies vont de 48 à 100 mètres carrés. ils disposent également d'ascenseurs, d'un parking, d'espaces verts et de cuisines ... En savoir plus",
#   'rooms': 2.0,
#   'surface': 81.0,
#   'city': 'casablanca',
#   'district': 'al azhar'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7480730/appartement-au-rdc-de-100m%C2%B2-en-vente-les-all%C3%A9es-de-californie-2',
#   'property_id': '7480730',
#   'price': 1498000.0,
#   'title': 'appartement au rdc de 100m² en vente les...',
#   'description': 'composée de 4 immeubles en r4, les allées de californie 2 est une résidence fermée et sécurisée située au quartier californie qui vous propose des appartements haut standing de 2 et 3 chambres, de ... En savoir plus',
#   'rooms': 3.0,
#   'surface': 100.0,
#   'city': 'casablanca',
#   'district': 'californie'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7468690/appartement-de-115m%C2%B2-en-vente-les-all%C3%A9es-de-californie-2',
#   'property_id': '7468690',
#   'price': 1887000.0,
#   'title': 'appartement de 115m² en vente les allées...',
#   'description': 'composée de 4 immeubles en r4, les allées de californie 2 est une résidence fermée et sécurisée située au quartier californie qui vous propose des appartements haut standing de 2 et 3 chambres, de ... En savoir plus',
#   'rooms': 3.0,
#   'surface': 115.0,
#   'city': 'casablanca',
#   'district': 'californie'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7259227/appartement-au-rdc-de-109m%C2%B2-en-vente-les-all%C3%A9es-de-californie-2',
#   'property_id': '7259227',
#   'price': 1651000.0,
#   'title': 'appartement au rdc de 109m² en vente les...',
#   'description': 'composée de 4 immeubles en r4, les allées de californie 2 est une résidence fermée et sécurisée située au quartier californie qui vous propose des appartements haut standing de 2 et 3 chambres, de ... En savoir plus',
#   'rooms': 3.0,
#   'surface': 109.0,
#   'city': 'casablanca',
#   'district': 'californie'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7259226/appartement-au-rdc-de-87m%C2%B2-en-vente-les-all%C3%A9es-de-californie-2',
#   'property_id': '7259226',
#   'price': 1329000.0,
#   'title': 'appartement au rdc de 87m² en vente les a...',
#   'description': 'composée de 4 immeubles en r4, les allées de californie 2 est une résidence fermée et sécurisée située au quartier californie qui vous propose des appartements haut standing de 2 et 3 chambres, de ... En savoir plus',
#   'rooms': 2.0,
#   'surface': 87.0,
#   'city': 'casablanca',
#   'district': 'californie'},
#  {'link': 'https://www.mubawab.ma/fr/p/3763/magasins-r%C3%A9sidences-diaz',
#   'property_id': None,
#   'price': 1271000.0,
#   'title': None,
#   'description': 'situé au maârif extension, le projet diaz vous propose des locaux commerciaux au niveau des rues brahim nakhai et mansour abidi, la superficie des commerces varie entre 41m² et 82,5m² à partir de 1.271.000 dh les locaux commerciaux ont été pensés et conçus pour exercer ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'maârif extension'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7623671/appartement-100m%C2%B2-en-vente-r%C3%A9sidence-al-badr',
#   'property_id': '7623671',
#   'price': 780000.0,
#   'title': 'appartement 100m² en vente, résidence al...',
#   'description': "le complexe résidentiel al-badr propose des appartements de haute qualité. ses superficies vont de 48 à 100 mètres carrés. ils disposent également d'ascenseurs, d'un parking, d'espaces verts et de cuisines ... En savoir plus",
#   'rooms': 3.0,
#   'surface': 100.0,
#   'city': 'casablanca',
#   'district': 'al azhar'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7602636/appartement-104m2-%C3%A0-californie-royal-park',
#   'property_id': '7602636',
#   'price': 1880000.0,
#   'title': 'appartement 104m2 à californie royal park',
#   'description': 'enveloppé dans un écrin verdoyant, royal park vous offre la quintessence du luxe et un service raffiné dans une atmosphère zen. cet appartement de 104 m2, situé au 1er étage comprend 2 chambres spacieuses, des ... En savoir plus',
#   'rooms': 2.0,
#   'surface': 104.0,
#   'city': 'casablanca',
#   'district': 'californie'},
#  {'link': 'https://www.mubawab.ma/fr/a/7636265/vente-appartement-ferme-bretonne',
#   'property_id': '7636265',
#   'price': 2750000.0,
#   'title': 'vente appartement ferme bretonne',
#   'description': "appartement disponible sur ferme bretonne dans un emplacement calme sans vis à vis vue sur la verdure ensoleillé immeuble sécurisé l'appartement comporte une climatisation centrale , avec double salon 3 ... En savoir plus",
#   'rooms': 3.0,
#   'surface': 150.0,
#   'city': 'casablanca',
#   'district': 'ferme bretonne (hay arraha)'},
#  {'link': 'https://www.mubawab.ma/fr/a/7704289/studio-%C3%A0-vendre-gautier',
#   'property_id': '7704289',
#   'price': 1320000.0,
#   'title': 'studio à vendre gautier',
#   'description': "studio à vendre gautier disponible à la livraison proche du consulat pour plus d'informations contactez nous",
#   'rooms': 1.0,
#   'surface': 65.0,
#   'city': 'casablanca',
#   'district': 'sidi belyout'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7259212/appartement-au-rdc-de-98m%C2%B2-en-vente-les-all%C3%A9es-de-californie-2',
#   'property_id': '7259212',
#   'price': 1511000.0,
#   'title': 'appartement au rdc de 98m² en vente les a...',
#   'description': 'composée de 4 immeubles en r4, les allées de californie 2 est une résidence fermée et sécurisée située au quartier californie qui vous propose des appartements haut standing de 2 et 3 chambres, de superficies ... En savoir plus',
#   'rooms': 3.0,
#   'surface': 98.0,
#   'city': 'casablanca',
#   'district': 'californie'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7259209/appartement-de-111m%C2%B2-en-vente-les-all%C3%A9es-de-californie-2',
#   'property_id': '7259209',
#   'price': 1823000.0,
#   'title': 'appartement de 111m² en vente les allées...',
#   'description': 'composée de 4 immeubles en r4, les allées de californie 2 est une résidence fermée et sécurisée située au quartier californie qui vous propose des appartements haut standing de 2 et 3 chambres, de superficies ... En savoir plus',
#   'rooms': 3.0,
#   'surface': 111.0,
#   'city': 'casablanca',
#   'district': 'californie'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7589613/appartement-de-50-m%C2%B2-en-vente-r%C3%A9sidence-jnan-sbil',
#   'property_id': '7589613',
#   'price': 250000.0,
#   'title': 'appartement de 50 m² en vente, résidence...',
#   'description': 'ikamati group annonce le lancement de son nouveau projet « jnan sbil » le projet jnan sbil se distingue par son emplacement stratégique entre bernoussi et echo zenata, à proximité des axes routiers, de ... En savoir plus',
#   'rooms': 2.0,
#   'surface': 50.0,
#   'city': 'casablanca',
#   'district': 'bernoussi'},
#  {'link': 'https://www.mubawab.ma/fr/a/7642058/studio-en-vente-%C3%A0-palmier',
#   'property_id': '7642058',
#   'price': nan,
#   'title': 'studio en vente à palmier',
#   'description': "l'idéal si vous souhaitez acheter un studio à palmier pour habitation ou investissement . différentes superficies à partir de 39m2 tous les studios vue extérieur finition pointue haut standing",
#   'rooms': 1.0,
#   'surface': 42.0,
#   'city': 'casablanca',
#   'district': 'palmier'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7623672/appartement-97m%C2%B2-en-vente-r%C3%A9sidence-al-badr',
#   'property_id': '7623672',
#   'price': 770000.0,
#   'title': 'appartement 97m² en vente, résidence al b...',
#   'description': "le complexe résidentiel al-badr propose des appartements de haute qualité. ses superficies vont de 48 à 100 mètres carrés. ils disposent également d'ascenseurs, d'un parking, d'espaces verts et de cuisines ... En savoir plus",
#   'rooms': 3.0,
#   'surface': 97.0,
#   'city': 'casablanca',
#   'district': 'al azhar'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7598591/vend-appartement-%C3%A0-ma%C3%A2rif-superficie-119-m%C2%B2',
#   'property_id': '7598591',
#   'price': 1953000.0,
#   'title': 'vend appartement à maârif. superficie 119...',
#   'description': "faites une belle affaire en achetant cet appartement. prix 1 953 000 dh. 3 chambres, 2 salles de bains, 119 m². appréciez le confort de la climatisation. la résidence dispose également d'un service de concierge ... En savoir plus",
#   'rooms': 3.0,
#   'surface': 119.0,
#   'city': 'casablanca',
#   'district': 'maârif'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7623667/appartement-96m%C2%B2-en-vente-r%C3%A9sidence-al-badr',
#   'property_id': '7623667',
#   'price': 800000.0,
#   'title': 'appartement 96m² en vente, résidence al b...',
#   'description': "le complexe résidentiel al-badr propose des appartements de haute qualité. ses superficies vont de 48 à 100 mètres carrés. ils disposent également d'ascenseurs, d'un parking, d'espaces verts et de cuisines ... En savoir plus",
#   'rooms': 3.0,
#   'surface': 96.0,
#   'city': 'casablanca',
#   'district': 'al azhar'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7542427/appartement-de-140m%C2%B2-pond%C3%A9r%C3%A9e-2-chambres-r%C3%A9sidence-louise',
#   'property_id': '7542427',
#   'price': 3167100.0,
#   'title': 'appartement de 140m² pondérée 2 chambres...',
#   'description': 'ref: f502 : prix de vente : 3 619 000 dhs -- campagne promotionnelle : 3 167 100 dhs appartement dispose de 96m² habitable, de 75m² de terrasse - place de parking de 19m² et un box de 2m² erigé sur le ... En savoir plus',
#   'rooms': 2.0,
#   'surface': 140.0,
#   'city': 'casablanca',
#   'district': 'casablanca finance city'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7589600/appartement-de-50-m%C2%B2-en-vente-r%C3%A9sidence-jnan-sbil',
#   'property_id': '7589600',
#   'price': 250000.0,
#   'title': 'appartement de 50 m² en vente, résidence...',
#   'description': 'ikamati group annonce le lancement de son nouveau projet « jnan sbil » le projet jnan sbil se distingue par son emplacement stratégique entre bernoussi et echo zenata, à proximité des axes routiers, de ... En savoir plus',
#   'rooms': 2.0,
#   'surface': 50.0,
#   'city': 'casablanca',
#   'district': 'bernoussi'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7592459/vente-d-un-bel-appartement-%C3%A0-ain-diab-extension-surface-totale-121-m%C2%B2',
#   'property_id': '7592459',
#   'price': 1950000.0,
#   'title': "vente d'un bel appartement à ain diab ext...",
#   'description': 'idéalement situé aux portes de ain diab, à seulement deux kilomètres du morocco mall, anfa heaven a été conçu pour offrir un cadre de vie paisible et doux qui rompt avec le tumulte de la capitale économique. ... En savoir plus',
#   'rooms': 3.0,
#   'surface': 121.0,
#   'city': 'casablanca',
#   'district': 'ain diab extension'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7208458/appartement-123m2-%C3%A0-californie-royal-park',
#   'property_id': '7208458',
#   'price': 2151000.0,
#   'title': 'appartement 123m2 à californie royal park',
#   'description': 'enveloppé dans un écrin verdoyant, royal park vous offre la quintessence du luxe et un service raffiné dans une atmosphère zen. cet appartement de 123 m2, situé en rdc comprend 2 chambres spacieuses, des salles ... En savoir plus',
#   'rooms': 2.0,
#   'surface': 123.0,
#   'city': 'casablanca',
#   'district': 'californie'},
#  {'link': 'https://www.mubawab.ma/fr/a/7712735/appartement-%C3%A0-vendre-%C3%A0-a%C3%AFn-seba%C3%A2-2-belles-chambres',
#   'property_id': '7712735',
#   'price': 400000.0,
#   'title': 'appartement à vendre à aïn sebaâ. 2 belle...',
#   'description': 'appartement idéal à la vente. prix 400 000 dh. 2 chambres, 1 salle de bains, 62 m². 1 salon . 4ème étage. moins de 30 ans. cet appartement est proposé à la vente à aïn sebaâ, casablanca. proche de toutes ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'aïn sebaâ'},
#  {'link': 'https://www.mubawab.ma/fr/a/7712577/bel-appartement-de-140-m2-%C3%A0-vendre-%C3%A0-oulfa',
#   'property_id': '7712577',
#   'price': 1520000.0,
#   'title': 'bel appartement de 140 m2 à vendre à oulf...',
#   'description': "l'appartement est situé au 3ème et dernier étage d'une résidence surplombant la falaise de l’étang de oulfa. orienté sud, bien ensoleillé et sans vis à vis, l’appartement offre une vue panoramique ... En savoir plus",
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'oulfa'},
#  {'link': 'https://www.mubawab.ma/fr/a/7712347/sublime-appartement-sur-bd-al-massira-al-khadra',
#   'property_id': '7712347',
#   'price': 4400000.0,
#   'title': 'sublime appartement sur bd al massira al...',
#   'description': 'sublime appartement sur le boulevard al massira al khadra au 4eme etage sans vis a vis pleins sud un seul appartement par etage 3 chambre 3 salle de bain 2 place de parking 180 m2 reffait a neuf',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': "triangle d'or"},
#  {'link': 'https://www.mubawab.ma/fr/a/7711273/appartement-ensoleill%C3%A9-dans-r%C3%A9sidence-s%C3%A9curis%C3%A9e',
#   'property_id': '7711273',
#   'price': 1250000.0,
#   'title': 'appartement ensoleillé dans résidence séc...',
#   'description': "joli appartement au 4ème étage d'une résidence avec jardins située en face de la mosquée kzabri à quartier nassim. l'appartement est très bien agencé, a 2 façades (une façade sud qui donne sur l'extérieur ... En savoir plus",
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'sidi maarouf'},
#  {'link': 'https://www.mubawab.ma/fr/a/7707967/bel-appartement-terrasse-val-fleuri-casablanca',
#   'property_id': '7707967',
#   'price': 1560000.0,
#   'title': 'bel appartement terrasse val fleuri casab...',
#   'description': 'appartement val fleuri - 5ème etage - idéalement situé dans large impasse très sûre avec jardin 103 m² habitables avec 14m² de terrasse / pergola et 21 m² de garage titré, soit 120,5 m² ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'val fleury'},
#  {'link': 'https://www.mubawab.ma/fr/a/7707463/3-pi%C3%A8ces-luxueux-orient%C3%A9-sud-la-cit%C3%A9-des-arts',
#   'property_id': '7707463',
#   'price': 2956000.0,
#   'title': '3 pièces luxueux orienté sud la cité des...',
#   'description': 'rare : grand 3 pièces orienté sud de 124m², dont balcon de 4m² avec vue dégagée sur la place des arts et buanderie de 3m², achevé en 2018. place de parking au sous-sol de 10m² inclue. un hall avec wc de ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'bourgogne ouest'},
#  {'link': 'https://www.mubawab.ma/fr/a/7707251/appartement-2-mars',
#   'property_id': '7707251',
#   'price': nan,
#   'title': 'appartement 2 mars',
#   'description': 'une résidence au quartier 2 mars avec un emplacement stratégique à proximité de toute commodité . appartements haut standing de 85 m2 de 2 chambres salon avec suite parentale et parking titré de 11 m2. ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'maârif extension'},
#  {'link': 'https://www.mubawab.ma/fr/a/7704766/duplex-avec-acc%C3%A8s-%C3%A0-la-corniche',
#   'property_id': '7704766',
#   'price': 2300000.0,
#   'title': 'duplex avec accès à la corniche',
#   'description': 'je mets en vente un beau duplex ensoleillé, orienté est, de 118m2 avec une place de garage titrée, dans une résidence fermée et sécurisée. le duplex donne sur un petit jardin et comprend: un double salon, ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'bourgogne ouest'},
#  {'link': 'https://www.mubawab.ma/fr/a/7704635/tr%C3%A8s-bel-appartement-meubl%C3%A9-107-m2-r-du-palais',
#   'property_id': '7704635',
#   'price': 1630000.0,
#   'title': 'très bel appartement meublé, 107 m2 r du...',
#   'description': '**belle opportunité de vente** particulier mets en vente un très bel appartement avec excellente finition. prix : 1 630 000 (légèrement négociable) le bien dispose de 3 pièces dont une suite parentale ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'beauséjour'},
#  {'link': 'https://www.mubawab.ma/fr/a/7704504/bel-appartement-les-princesses',
#   'property_id': '7704504',
#   'price': 1850000.0,
#   'title': 'bel appartement les princesses',
#   'description': "bel appart de 131 m² avec garage et box terrasse titrés (16 m² en plus) dans une résidence haut standing très bien entretenue. grand salon 1 suite parentale 2 chambres cuisine équipée. l'appart compte ... En savoir plus",
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'les princesses'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7259224/appartement-de-115m%C2%B2-en-vente-les-all%C3%A9es-de-californie-2',
#   'property_id': '7259224',
#   'price': 1967000.0,
#   'title': 'appartement de 115m² en vente les allées...',
#   'description': 'composée de 4 immeubles en r4, les allées de californie 2 est une résidence fermée et sécurisée située au quartier californie qui vous propose des appartements haut standing de 2 et 3 chambres, de ... En savoir plus',
#   'rooms': 3.0,
#   'surface': 115.0,
#   'city': 'casablanca',
#   'district': 'californie'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7259215/appartement-de-106m%C2%B2-en-vente-les-all%C3%A9es-de-californie-2',
#   'property_id': '7259215',
#   'price': 1777000.0,
#   'title': 'appartement de 106m² en vente les allées...',
#   'description': 'composée de 4 immeubles en r4, les allées de californie 2 est une résidence fermée et sécurisée située au quartier californie qui vous propose des appartements haut standing de 2 et 3 chambres, de ... En savoir plus',
#   'rooms': 3.0,
#   'surface': 106.0,
#   'city': 'casablanca',
#   'district': 'californie'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7259213/appartement-au-rdc-de-105m%C2%B2-en-vente-les-all%C3%A9es-de-californie-2',
#   'property_id': '7259213',
#   'price': 1570000.0,
#   'title': 'appartement au rdc de 105m² en vente les...',
#   'description': 'composée de 4 immeubles en r4, les allées de californie 2 est une résidence fermée et sécurisée située au quartier californie qui vous propose des appartements haut standing de 2 et 3 chambres, de ... En savoir plus',
#   'rooms': 3.0,
#   'surface': 105.0,
#   'city': 'casablanca',
#   'district': 'californie'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7259211/appartement-de-111m%C2%B2-en-vente-les-all%C3%A9es-de-californie-2',
#   'property_id': '7259211',
#   'price': 1924000.0,
#   'title': 'appartement de 111m² en vente les allées...',
#   'description': 'composée de 4 immeubles en r4, les allées de californie 2 est une résidence fermée et sécurisée située au quartier californie qui vous propose des appartements haut standing de 2 et 3 chambres, de ... En savoir plus',
#   'rooms': 3.0,
#   'surface': 111.0,
#   'city': 'casablanca',
#   'district': 'californie'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7259210/appartement-de-84m%C2%B2-en-vente-les-all%C3%A9es-de-californie-2',
#   'property_id': '7259210',
#   'price': 1501000.0,
#   'title': 'appartement de 84m² en vente les allées d...',
#   'description': 'composée de 4 immeubles en r4, les allées de californie 2 est une résidence fermée et sécurisée située au quartier californie qui vous propose des appartements haut standing de 2 et 3 chambres, de ... En savoir plus',
#   'rooms': 2.0,
#   'surface': 84.0,
#   'city': 'casablanca',
#   'district': 'californie'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7391319/appartement-de-49m%C2%B2-avec-10m%C2%B2-de-cours-en-vente-as-living',
#   'property_id': '7391319',
#   'price': 601000.0,
#   'title': 'appartement de 49m² avec 10m² de cours en...',
#   'description': 'le projet résidentiel « as living » est le nouveau symbole de modernité au quartier ain sebaâ. le projet propose des appartements et studios de standing allant de 49 à 108 m² à partir 581.000 dh. · 1 à 3 ... En savoir plus',
#   'rooms': 1.0,
#   'surface': 54.0,
#   'city': 'casablanca',
#   'district': 'aïn sebaâ'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7592460/appartement-en-vente-%C3%A0-ain-diab-extension-surface-de-121-m%C2%B2',
#   'property_id': '7592460',
#   'price': 2140000.0,
#   'title': 'appartement en vente à ain diab extension...',
#   'description': 'idéalement situé aux portes de ain diab, à seulement deux kilomètres du morocco mall, anfa heaven a été conçu pour offrir un cadre de vie paisible et doux qui rompt avec le tumulte de la capitale ... En savoir plus',
#   'rooms': 2.0,
#   'surface': 198.0,
#   'city': 'casablanca',
#   'district': 'ain diab extension'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7673400/appartement-de-54m%C2%B2-en-vente-r%C3%A9sidence-studio-31',
#   'property_id': '7673400',
#   'price': 1072000.0,
#   'title': 'appartement de 54m² en vente résidence st...',
#   'description': 'studio 31 : les nouveaux studios où il faut investir à casablanca ! que vous soyez jeune actif, investisseur ou simplement à la recherche de votre futur logement à casablanca, le projet studio 31 vous ... En savoir plus',
#   'rooms': 1.0,
#   'surface': 54.0,
#   'city': 'casablanca',
#   'district': 'les hôpitaux'},
#  {'link': 'https://www.mubawab.ma/fr/p/3689/blue-skies',
#   'property_id': None,
#   'price': 861000.0,
#   'title': None,
#   'description': 'que vous soyez jeune actif, investisseur ou simplement à la recherche de votre futur logement à casablanca, le projet studio blue skies vous propose des biens qui correspondent en tous points à vos attentes plus qu’un simple projet, blue skies correspondra à l’ensemble de ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'riviera'},
#  {'link': 'https://www.mubawab.ma/fr/a/7540219/appartment-a-vendre-bien-situ%C3%A9-a-2-mars',
#   'property_id': '7540219',
#   'price': 1590000.0,
#   'title': 'appartment a vendre bien situé a 2 mars',
#   'description': 'je mets en vente un bel appartement situé au quartier 2 mars dans une ruelle très calme, il est très bien agencé et bien ensoleillé (orienté sud) dans une résidence gardée 24/24 et 7/7 avec des caméras de ... En savoir plus',
#   'rooms': 2.0,
#   'surface': 113.0,
#   'city': 'casablanca',
#   'district': 'mers sultan'},
#  {'link': 'https://www.mubawab.ma/fr/a/7462267/appartement-%C3%A0-vendre-a-mers-sultan-c-une-terrasse',
#   'property_id': '7462267',
#   'price': 870000.0,
#   'title': 'appartement à vendre a mers sultan c une...',
#   'description': 'appartement a mers sultan a vendre avec une terrasse, il se compose de : 2 chambres ,une salle de bain ,un salon, une cuisine bien équipée dans une résidence avec ascenseur, bon affaire pour investissement ... En savoir plus',
#   'rooms': 2.0,
#   'surface': 71.0,
#   'city': 'casablanca',
#   'district': 'mers sultan'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7598788/appartement-en-vente-%C3%A0-ahl-loghlam-hay-assalam-3-chambres',
#   'property_id': '7598788',
#   'price': 455000.0,
#   'title': 'appartement en vente à ahl loghlam hay as...',
#   'description': 'c’est au cœur de la ville nouvelle de tit mellil, à 2mins seulement de l’autoroute périphérique et 20mins seulement de l’aéroport mohamed v, que shems al madina vous fait découvrir sa nouvelle résidence « ... En savoir plus',
#   'rooms': 3.0,
#   'surface': 110.0,
#   'city': 'casablanca',
#   'district': 'ahl loghlam (hay assalam)'},
#  {'link': 'https://www.mubawab.ma/fr/a/7596522/bel-appartement-en-bon-%C3%A9tat-et-tr%C3%A8s-bien-situ%C3%A9',
#   'property_id': '7596522',
#   'price': 1680000.0,
#   'title': 'bel appartement en bon état et très bien...',
#   'description': "emplacement prime au triangle d'or casablanca - vente d'un bel appartement lumineux de 103 m² habitables - balcons - 2 chambres - 1.680.000 dhs (149.000 ) triangle d'or / sijilmassi, à proximité immédiate du ... En savoir plus",
#   'rooms': 2.0,
#   'surface': 103.0,
#   'city': 'casablanca',
#   'district': 'racine extension'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7596072/appartement-%C3%A0-l-achat-%C3%A0-ahl-loghlam-hay-assalam-3-chambres',
#   'property_id': '7596072',
#   'price': 250000.0,
#   'title': "appartement à l'achat à ahl loghlam hay a...",
#   'description': 'c’est au cœur de la ville nouvelle de tit mellil, à 2mins seulement de l’autoroute périphérique et 20 mins seulement de l’aéroport mohamed v, que shems al madina vous fait découvrir sa nouvelle résidence « ... En savoir plus',
#   'rooms': 3.0,
#   'surface': 67.0,
#   'city': 'casablanca',
#   'district': 'ahl loghlam (hay assalam)'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7589614/appartement-de-50-m%C2%B2-en-vente-r%C3%A9sidence-jnan-sbil',
#   'property_id': '7589614',
#   'price': 250000.0,
#   'title': 'appartement de 50 m² en vente, résidence...',
#   'description': 'ikamati group annonce le lancement de son nouveau projet « jnan sbil » le projet jnan sbil se distingue par son emplacement stratégique entre bernoussi et echo zenata, à proximité des axes routiers, de ... En savoir plus',
#   'rooms': 2.0,
#   'surface': 50.0,
#   'city': 'casablanca',
#   'district': 'bernoussi'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7596069/vend-appartement-%C3%A0-ahl-loghlam-hay-assalam-surface-totale-67-m%C2%B2',
#   'property_id': '7596069',
#   'price': 250000.0,
#   'title': 'vend appartement à ahl loghlam hay assala...',
#   'description': 'c’est au cœur de la ville nouvelle de tit mellil, à 2mins seulement de l’autoroute périphérique et 20 mins seulement de l’aéroport mohamed v, que shems al madina vous fait découvrir sa nouvelle résidence « ... En savoir plus',
#   'rooms': 3.0,
#   'surface': 67.0,
#   'city': 'casablanca',
#   'district': 'ahl loghlam (hay assalam)'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7596063/superbe-appartement-%C3%A0-vendre-%C3%A0-ahl-loghlam-hay-assalam-surface-totale-67-m%C2%B2',
#   'property_id': '7596063',
#   'price': 250000.0,
#   'title': 'superbe appartement à vendre à ahl loghla...',
#   'description': 'c’est au cœur de la ville nouvelle de tit mellil, à 2mins seulement de l’autoroute périphérique et 20 mins seulement de l’aéroport mohamed v, que shems al madina vous fait découvrir sa nouvelle résidence « ... En savoir plus',
#   'rooms': 3.0,
#   'surface': 67.0,
#   'city': 'casablanca',
#   'district': 'ahl loghlam (hay assalam)'},
#  {'link': 'https://www.mubawab.ma/fr/a/7608959/studios-haut-standing-meubl%C3%A9-ma%C3%A2rif',
#   'property_id': '7608959',
#   'price': 1000000.0,
#   'title': 'studios haut standing meublé maârif',
#   'description': "z luxury immo vous propose à la vente ce superbe studio situé au 5ème et dernier étage d'une résidence sécurisée 24h/24 au coeur du quartier mâarif. entièrement meublé et très cosy, il se compose d'un salon ... En savoir plus",
#   'rooms': 1.0,
#   'surface': 46.0,
#   'city': 'casablanca',
#   'district': 'maârif'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7391309/appartement-de-105m%C2%B2-en-vente-as-living',
#   'property_id': '7391309',
#   'price': 1086000.0,
#   'title': 'appartement de 105m² en vente as living',
#   'description': 'le projet résidentiel « as living » est le nouveau symbole de modernité au quartier ain sebaâ. le projet propose des appartements et studios de standing allant de 49 à 108 m² à partir 581.000 dh. · 1 à 3 ... En savoir plus',
#   'rooms': 3.0,
#   'surface': 105.0,
#   'city': 'casablanca',
#   'district': 'aïn sebaâ'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7654226/vend-appartement-%C3%A0-a%C3%AFn-seba%C3%A2-3-belles-chambres',
#   'property_id': '7654226',
#   'price': 980400.0,
#   'title': 'vend appartement à aïn sebaâ. 3 belles ch...',
#   'description': 'découvrez cet appartement à vendre. prix 980 400 dh. 4 pièces, 2 salles de bains privatives, 88 m². 3 chambres à coucher. nouveau. sécurité. venez découvrir cet appartement à vendre à aïn sebaâ, casablanca.',
#   'rooms': 3.0,
#   'surface': 88.0,
#   'city': 'casablanca',
#   'district': 'aïn sebaâ'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7591857/studio-de-56m%C2%B2-dont-7m%C2%B2-de-balcon',
#   'property_id': '7591857',
#   'price': 1050000.0,
#   'title': 'studio de 56m² dont 7m² de balcon',
#   'description': 'le projet est érigée en r5, situé dans l’un des quartiers les plus recherchés de la ville de casablanca, à savoir maarif sur boulevard yacoub mansour, proposant des studios haut standing d’une superficie de 38 ... En savoir plus',
#   'rooms': 1.0,
#   'surface': 56.0,
#   'city': 'casablanca',
#   'district': 'les princesses'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7542465/appartement-de-167m%C2%B2-pond%C3%A9r%C3%A9e-3-chambres-r%C3%A9sidence-louise',
#   'property_id': '7542465',
#   'price': 3579120.0,
#   'title': 'appartement de 167m² pondérée 3 chambres...',
#   'description': 'ref: e101 : prix de vente : 4 076 800 dhs -- campagne promotionnelle : 3 579 120 dhs appartement dispose de 141m² habitable, de 31m² de terrasse - 2 place de parking de 28m² et un box de 4m² erigé sur le ... En savoir plus',
#   'rooms': 3.0,
#   'surface': 167.0,
#   'city': 'casablanca',
#   'district': 'casablanca finance city'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7598789/appartement-%C3%A0-l-achat-%C3%A0-ahl-loghlam-hay-assalam-surface-de-83-m%C2%B2',
#   'property_id': '7598789',
#   'price': 360000.0,
#   'title': "appartement à l'achat à ahl loghlam hay a...",
#   'description': 'c’est au cœur de la ville nouvelle de tit mellil, à 2mins seulement de l’autoroute périphérique et 20mins seulement de l’aéroport mohamed v, que shems al madina vous fait découvrir sa nouvelle résidence « ... En savoir plus',
#   'rooms': 3.0,
#   'surface': 83.0,
#   'city': 'casablanca',
#   'district': 'ahl loghlam (hay assalam)'},
#  {'link': 'https://www.mubawab.ma/fr/a/7706652/studio-a-la-vente-a-racine',
#   'property_id': '7706652',
#   'price': 1300000.0,
#   'title': 'studio a la vente a racine',
#   'description': "global services immobilier vous propose à la location ce studio de 45m², situé dans l'une des résidences les plus prisées du quartier racine - casablanca. le studio se compose de : - un salon moderne, - une ... En savoir plus",
#   'rooms': 1.0,
#   'surface': 45.0,
#   'city': 'casablanca',
#   'district': 'racine'},
#  {'link': 'https://www.mubawab.ma/fr/a/7704339/appartement-en-plein-maarif-%C3%A0-saisir',
#   'property_id': '7704339',
#   'price': 1750000.0,
#   'title': 'appartement en plein maarif à saisir',
#   'description': 'belle appartement en plein maarif , en parallèle rue al fourat , 132 m2 , terrasse , avec 2 façades , proximité carrefour , marjane market , patisserie prunel , maroc télécom... , 3 chanmbres , 2 salles de ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'maârif extension'},
#  {'link': 'https://www.mubawab.ma/fr/a/7701317/bel-appartement-sans-vis-%C3%A0-vis-a-bachkou',
#   'property_id': '7701317',
#   'price': 1670000.0,
#   'title': 'bel appartement sans vis à vis a bachkou',
#   'description': 'très bel appartement à bachkou vue dégagée sur polo en plein bvd taddart opportunité à saisir',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'quartier bachkou'},
#  {'link': 'https://www.mubawab.ma/fr/a/7700791/appartement-%C3%A0-cil-dernier-%C3%A9tage-plein-sud',
#   'property_id': '7700791',
#   'price': 2980000.0,
#   'title': 'appartement à cil dernier étage plein sud',
#   'description': 'je mets en vente mon appartement de 131 m2 en plein coeur du cil au dernier étage (5ieme), orientation plein sud, dans une résidence neuve (- de 5 ans) de très haut standing (domotique). il est à quelques ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'cil (hay salam)'},
#  {'link': 'https://www.mubawab.ma/fr/a/7700540/appartement-%C3%A0-vendre-%C3%A0-mers-sultan-2-grandes-pi%C3%A8ces-salon-traditionnel-et-syst%C3%A8me-d-antenne-parabolique-',
#   'property_id': '7700540',
#   'price': 120000000.0,
#   'title': 'appartement à vendre à mers sultan. 2 gra...',
#   'description': 'affaire à saisir pour cet appartement à vendre. prix 120 000 000 dh. 2 chambres, 2 salles de bains, 129 m². 2 pièces lumineuses. 1er étage. moins de 10 ans. revêtement: carrelage. confort et tradition avec ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'benjdia'},
#  {'link': 'https://www.mubawab.ma/fr/a/7698729/tr%C3%A8s-bel-appartement-%C3%A0-vendre',
#   'property_id': '7698729',
#   'price': 2350000.0,
#   'title': 'très bel appartement à vendre',
#   'description': "très bel appartement à vendre sur boulevard d'alexandrie, il se compose de 3 chambres qui donnent sur des balcons, 2 salles de bains avec une douche à l'italienne, un double salon qui donne aussi sur un ... En savoir plus",
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'mers sultan'},
#  {'link': 'https://www.mubawab.ma/fr/a/7690312/superbe-appartement-%C3%A0-vendre-%C3%A0-les-princesses-2-belles-chambres-antenne-parabolique-et-s%C3%A9curit%C3%A9',
#   'property_id': '7690312',
#   'price': 1690000.0,
#   'title': 'superbe appartement à vendre à les prince...',
#   'description': 'ne laissez pas passer cet appartement e à vendre en plein centre de casablanca, prix 1 690 000 dh. 2 chambres, 2 salles de bains, 95 m². 3 pièces lumineuses. 4ème étage. moins de 5 ans. revêtement: marbre ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'les princesses'},
#  {'link': 'https://www.mubawab.ma/fr/a/7688757/appartement-en-plein-centre-de-117m%C2%B2-z%C3%A9ro-travaux',
#   'property_id': '7688757',
#   'price': 1390000.0,
#   'title': 'appartement en plein centre de 117m² zéro...',
#   'description': "je met en vente ce très bel appartement en plein centre ville position rue d'alger bd rachidi et hassan ier. l'appartement comprend 2 chambres, un double salon, un hall, une salle de bain, une salle d'eau ... En savoir plus",
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'centre ville'},
#  {'link': 'https://www.mubawab.ma/fr/a/7688297/vente-appartement-casablanca',
#   'property_id': '7688297',
#   'price': 1000000.0,
#   'title': 'vente appartement casablanca',
#   'description': 'appartement 100 m², 3 chambres, cuisine, salon, 2 sdb 2 balcons, dans une résidence (résidence prestige el oulfa) sans vis à vis',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'hay zobir'},
#  {'link': 'https://www.mubawab.ma/fr/a/7688014/appartement-ain-diab-3-chambres',
#   'property_id': '7688014',
#   'price': 2300000.0,
#   'title': 'appartement ain diab 3 chambres',
#   'description': 'bel appartement à vendre situé à ain diab dans une résidence calme, sécurisée et proche de toutes les commodités : tramway littoral, épicerie, pharmacie,... surface : 142 m², 5 pièces, 3 chambres, 1 salle ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'ain diab'},
#  {'link': 'https://www.mubawab.ma/fr/a/7687029/app-r%C3%A9sidence-avec-jardin-plein-coeur-de-casa',
#   'property_id': '7687029',
#   'price': 1650000.0,
#   'title': 'app résidence avec jardin plein coeur de...',
#   'description': 'appartement 4ème étage, vue sur jardin dans une résidence très prisée au coeur du quartier maarif extension. 2 chambres salon, cuisine équipée et salle de bain. très bel ensoleillement toute la journée, ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'maârif extension'},
#  {'link': 'https://www.mubawab.ma/fr/a/7321869/studio-a-vendre-a-palmier-haut-standing',
#   'property_id': '7321869',
#   'price': nan,
#   'title': 'studio a vendre a palmier haut standing',
#   'description': "studio haut standing, avec une finition sur mesure composé d'un salon et une cuisine américaine équipé électroménager bosch une chambre avec balcon une salle de bain avec douche italienne garage ... En savoir plus",
#   'rooms': 1.0,
#   'surface': 49.0,
#   'city': 'casablanca',
#   'district': 'palmier'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7401075/appartement-de-96m%C2%B2-en-vente-les-jardins-de-ain-seba%C3%A2-2',
#   'property_id': '7401075',
#   'price': 1196000.0,
#   'title': 'appartement de 96m² en vente, les jardins...',
#   'description': 'les jardins de ain sebaâ 2 vous propose des appartements de standing d’une superficie allant de 71 à 96 m², et ce, à un prix 100% déclaré débutant à 924.000 dh ! entourée d’espaces verts, cette résidence ... En savoir plus',
#   'rooms': 3.0,
#   'surface': 96.0,
#   'city': 'casablanca',
#   'district': 'aïn sebaâ'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7598790/vend-appartement-%C3%A0-ahl-loghlam-hay-assalam-3-belles-chambres',
#   'property_id': '7598790',
#   'price': 340000.0,
#   'title': 'vend appartement à ahl loghlam hay assala...',
#   'description': 'c’est au cœur de la ville nouvelle de tit mellil, à 2mins seulement de l’autoroute périphérique et 20mins seulement de l’aéroport mohamed v, que shems al madina vous fait découvrir sa nouvelle résidence « ... En savoir plus',
#   'rooms': 3.0,
#   'surface': 82.0,
#   'city': 'casablanca',
#   'district': 'ahl loghlam (hay assalam)'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7654227/vend-appartement-%C3%A0-a%C3%AFn-seba%C3%A2-3-chambres-agr%C3%A9ables',
#   'property_id': '7654227',
#   'price': 1042000.0,
#   'title': 'vend appartement à aïn sebaâ. 3 chambres...',
#   'description': 'découvrez cet appartement à vendre. prix 1 042 000 dh. 4 pièces, 2 salles de bains, surface 92 m². 3 chambres à coucher. nouveau. sécurité assurée. idéal si vous souhaitez acheter un appartement à aïn ... En savoir plus',
#   'rooms': 3.0,
#   'surface': 92.0,
#   'city': 'casablanca',
#   'district': 'aïn sebaâ'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7306024/appartement-de-59m%C2%B2-en-vente-r%C3%A9sidence-studio-31',
#   'property_id': '7306024',
#   'price': 1141250.0,
#   'title': 'appartement de 59m² en vente résidence st...',
#   'description': 'studio 31 : les nouveaux studios où il faut investir à casablanca ! que vous soyez jeune actif, investisseur ou simplement à la recherche de votre futur logement à casablanca, le projet studio 31 vous ... En savoir plus',
#   'rooms': 1.0,
#   'surface': 59.0,
#   'city': 'casablanca',
#   'district': 'les hôpitaux'},
#  {'link': 'https://www.mubawab.ma/fr/pa/6881329/appartement-de-103m%C2%B2-en-vente-r%C3%A9sidence-%C3%B4-maarif',
#   'property_id': '6881329',
#   'price': 2005500.0,
#   'title': 'appartement de 103m² en vente résidence ô...',
#   'description': 'le projet ô maarif s’inscrit dans une volonté d’offrir l’expertise de la qualité et du haut standing à une clientèle jeune, dynamique et exigeante. idéalement situé entre les quartiers de maarif, gauthier ... En savoir plus',
#   'rooms': 2.0,
#   'surface': 103.0,
#   'city': 'casablanca',
#   'district': 'maârif'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7623080/appartement-de-120m%C2%B2-pond%C3%A9r%C3%A9e-2-chambres-r%C3%A9sidence-louise',
#   'property_id': '7623080',
#   'price': 2599020.0,
#   'title': 'appartement de 120m² pondérée 2 chambres...',
#   'description': 'ref: f001 : prix de vente : 2 987 800 dhs -- campagne promotionnelle : 2 599 020 dhs appartement dispose de 111m² habitable, de 8m² de terrasse erigé sur le site de l’ancien aéroport d’anfa, ... En savoir plus',
#   'rooms': 2.0,
#   'surface': 120.0,
#   'city': 'casablanca',
#   'district': 'casablanca finance city'},
#  {'link': 'https://www.mubawab.ma/fr/pa/6916161/appartement-de-74m%C2%B2-en-vente-les-jardins-de-belv%C3%A9d%C3%A8re',
#   'property_id': '6916161',
#   'price': 777000.0,
#   'title': 'appartement de 74m² en vente, les jardins...',
#   'description': 'complexe résidentiel et commercial composé de 4 tranches construites autour de grands jardins, où les enfants peuvent jouer en toute quiétude. entièrement sécurisée, la résidence « les jardins de ... En savoir plus',
#   'rooms': 2.0,
#   'surface': 74.0,
#   'city': 'casablanca',
#   'district': 'ain borja'},
#  {'link': 'https://www.mubawab.ma/fr/p/3688/natura-living',
#   'property_id': None,
#   'price': nan,
#   'title': None,
#   'description': 'natura living, un lieu mythique au cœur de mohammedia natura une résidence fermée qui célèbre la beauté et la grandeur de la nature en offrant à ses résidents en quête de tranquillité et d’équilibre, un cadre de vie exclusif et sécurisé. nichée dans un écrin de verdure , ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'mohammedia',
#   'district': 'centre ville'},
#  {'link': 'https://www.mubawab.ma/fr/a/7706286/l%E2%80%99appartement-a-la-vente-racine',
#   'property_id': '7706286',
#   'price': 3400000.0,
#   'title': 'l’appartement a la vente racine',
#   'description': "global services immobilier vous propose à la location cet appartement de 183m², un immeuble presque neuf, situé dans l'une des résidences les plus prisées du quartier racine - casablanca. au 4éme étage avec ... En savoir plus",
#   'rooms': 3.0,
#   'surface': 183.0,
#   'city': 'casablanca',
#   'district': 'racine'},
#  {'link': 'https://www.mubawab.ma/fr/a/7689772/appart-duplex-meubl%C3%A9-%C3%A0-la-location-%C3%A0-racine',
#   'property_id': '7689772',
#   'price': 19500.0,
#   'title': 'appart duplex meublé à la location à raci...',
#   'description': "global services immobilier vous propose à la location cet appartement duplex moderne, de 125 m² situé dans l'une des résidences les plus prisées du quartier racine - casablanca. au 3éme étage avec une ... En savoir plus",
#   'rooms': 2.0,
#   'surface': 125.0,
#   'city': 'casablanca',
#   'district': 'racine'},
#  {'link': 'https://www.mubawab.ma/fr/a/7679401/sublime-appartement-%C3%A0-vendre-sur-la-ferme-bretonne',
#   'property_id': '7679401',
#   'price': 1750000.0,
#   'title': 'sublime appartement à vendre sur la ferme...',
#   'description': "immo partners vous propose en vente un magnifique appartement de 103m2 au 2eme étage d'un immeuble neuf et sécurisé sur la ferme bretonne. l'appartement es orienté sud et se compose d'un double salon, une ... En savoir plus",
#   'rooms': 2.0,
#   'surface': 103.0,
#   'city': 'casablanca',
#   'district': 'ferme bretonne (hay arraha)'},
#  {'link': 'https://www.mubawab.ma/fr/a/7691751/magnifique-appartement-%C3%A0-vendre-sur-cfc',
#   'property_id': '7691751',
#   'price': 1890000.0,
#   'title': 'magnifique appartement à vendre sur cfc',
#   'description': "immo partners vous propose en vente un magnifique appartement de 114m² située au premier étage dans un cadre d'exception, sécurisée et calme sur casa finance city. cet magnifique appartement se compose d'un ... En savoir plus",
#   'rooms': 2.0,
#   'surface': 114.0,
#   'city': 'casablanca',
#   'district': 'casablanca finance city'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7589599/appartement-de-50-m%C2%B2-en-vente-r%C3%A9sidence-jnan-sbil',
#   'property_id': '7589599',
#   'price': 250000.0,
#   'title': 'appartement de 50 m² en vente, résidence...',
#   'description': 'ikamati group annonce le lancement de son nouveau projet « jnan sbil » le projet jnan sbil se distingue par son emplacement stratégique entre bernoussi et echo zenata, à proximité des axes routiers, de ... En savoir plus',
#   'rooms': 2.0,
#   'surface': 50.0,
#   'city': 'casablanca',
#   'district': 'bernoussi'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7682015/studio-neuf-de-33-m%C2%B2-%C3%A0-vendre-%C3%A0-sidi-maarouf',
#   'property_id': '7682015',
#   'price': 629000.0,
#   'title': 'studio neuf de 33 m² à vendre à sidi maar...',
#   'description': "studio d’exception à vendre avec des finitions haut standing d’une superficie de 33 m² 3m² de balcon au sein du projet evasion square à sidi maarouf. conçu pour maximiser l'espace de vie et situé dans un ... En savoir plus",
#   'rooms': 1.0,
#   'surface': 33.0,
#   'city': 'casablanca',
#   'district': 'sidi maarouf'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7654221/bel-appartement-%C3%A0-vendre-%C3%A0-a%C3%AFn-seba%C3%A2-superficie-52-m%C2%B2',
#   'property_id': '7654221',
#   'price': 607800.0,
#   'title': 'bel appartement à vendre à aïn sebaâ. sup...',
#   'description': 'opportunité unique pour cet appartement à vendre. prix 607 800 dh. 2 chambres à coucher, 2 salles de bains, 52 m². 3 pièces lumineuses. 1er étage. nouveau. sécurité. cet appartement est proposé à la vente à ... En savoir plus',
#   'rooms': 2.0,
#   'surface': 52.0,
#   'city': 'casablanca',
#   'district': 'aïn sebaâ'},
#  {'link': 'https://www.mubawab.ma/fr/a/7609179/prestigieux-appartement-%C3%A0-vendre-au-cil',
#   'property_id': '7609179',
#   'price': 2500000.0,
#   'title': 'prestigieux appartement à vendre au cil',
#   'description': 'ce prestigieux appartement est à l’achat situé dans le quartier du cil dans une résidence de haut standing l’appartement se compose de trois chambres salon cuisine deux salles de bain la troisième chambre est ... En savoir plus',
#   'rooms': 3.0,
#   'surface': 140.0,
#   'city': 'casablanca',
#   'district': 'cil (hay salam)'},
#  {'link': 'https://www.mubawab.ma/fr/a/7654721/bel-appartement-%C3%A0-vendre-%C3%A0-les-princesses',
#   'property_id': '7654721',
#   'price': 1350000.0,
#   'title': 'bel appartement à vendre à les princesses',
#   'description': 'cet bel appartement lumineux et spacieux est à l’achat situé dans le quartier des princesses chic et bien réputé bon emplacement et bon investissement l’appartement est situé dans une résidence de haut ... En savoir plus',
#   'rooms': 2.0,
#   'surface': 99.0,
#   'city': 'casablanca',
#   'district': 'les princesses'},
#  {'link': 'https://www.mubawab.ma/fr/a/7451183/terrasse-dernier-etage',
#   'property_id': '7451183',
#   'price': 2100000.0,
#   'title': 'terrasse dernier etage',
#   'description': 'princesses : appartement de 167 m2 dont 40m2 de terrasse sans aucun vis-à-vis. appartement traversant, ensoleillé matin et après-midi au 5ème et dernier étage de la résidence. situé derrière marjane ghandi ... En savoir plus',
#   'rooms': 3.0,
#   'surface': 167.0,
#   'city': 'casablanca',
#   'district': 'casablanca'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7623072/duplex-de-323m%C2%B2-pond%C3%A9r%C3%A9e-3-chambres-r%C3%A9sidence-louise',
#   'property_id': '7623072',
#   'price': 8482010.0,
#   'title': 'duplex de 323m² pondérée 3 chambres, rési...',
#   'description': 'ref: j903 : prix de vente : 9 524 460 dhs -- campagne promotionnelle : 8 482 014 dhs duplex dispose de 200m² habitable, de 116m² de terrasse et 102m² de jardin - 2 place de parking de 31m² et un box de ... En savoir plus',
#   'rooms': 3.0,
#   'surface': 323.0,
#   'city': 'casablanca',
#   'district': 'casablanca finance city'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7623674/appartement-69m%C2%B2-en-vente-r%C3%A9sidence-al-badr',
#   'property_id': '7623674',
#   'price': 600000.0,
#   'title': 'appartement 69m² en vente, résidence al b...',
# ...
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'sidi moumen'},
#  {'link': 'https://www.mubawab.ma/fr/a/7708936/appartement-1-chambre-%C3%A0-louer-centre-ville',
#   'property_id': '7708936',
#   'price': 7000.0,
#   'title': 'appartement 1 chambre à louer centre vill...',
#   'description': 'appartement 1 chambre à louer au centre ville de casablanca se composant de : 1 chambre, 1 salon, 1 salle de bain, 1 terrasse et 1 place de parking.',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'sidi belyout'},
#  {'link': 'https://www.mubawab.ma/fr/a/7708909/dv-795-appartement-de-76-m%C2%B2-%C3%A0-ferme-bretonne',
#   'property_id': '7708909',
#   'price': 1185750.0,
#   'title': 'dv. 795: appartement de 76 m² à ferme bre...',
#   'description': "à louer, un superbe appartement avec une terrasse de 76 m² très ensoleillée, situé au rez-de-chaussée d'une belle résidence neuve à hay raha (ferme bretonne). il comprend : - un salon avec vue sur la ... En savoir plus",
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'ferme bretonne (hay arraha)'},
#  {'link': 'https://www.mubawab.ma/fr/a/7708863/rez-de-chauss%C3%A9e',
#   'property_id': '7708863',
#   'price': 420000.0,
#   'title': 'rez de chaussée',
#   'description': "j' ai un rez-de-chaussée à vendre , très proche du souk korea.peut facilement servir comme local pour dépôt de marchandise. situé dans une maison de un étage; c'est une copropriété et vous avez droit à la ... En savoir plus",
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'derb koréa'},
#  {'link': 'https://www.mubawab.ma/fr/a/7653266/appartement-a-vendre-bourgogne',
#   'property_id': '7653266',
#   'price': 1650000.0,
#   'title': 'appartement a vendre bourgogne',
#   'description': 'joli appartement a bourgogne d une surface 132 m enface de lycée lyautey très bien agence contient 3 chambre salon cuisine équipée 2sdb place au garage près de tout les commodités ensoleillé ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'bourgogne ouest'},
#  {'link': 'https://www.mubawab.ma/fr/a/7708719/opportunit%C3%A9-%C3%A0-saisir',
#   'property_id': '7708719',
#   'price': 165000000.0,
#   'title': 'opportunité à saisir',
#   'description': 'jolie appartement à vendre, bien ensoleillé, d’une superficie de 110m2 avec deux façades, dans un immeuble moderne de 5 étages avec ascenseur sur une ruelle calme du boulevard 2 mars, proche de toutes les ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'anfa supérieur'},
#  {'link': 'https://www.mubawab.ma/fr/a/7659325/apparts-neufs-%C3%A0-vendre-%C3%A0-oasis-2-%C3%A0-3chambres',
#   'property_id': '7659325',
#   'price': 1580000.0,
#   'title': 'apparts neufs à vendre à oasis 2 à 3chamb...',
#   'description': 'dans une nouvelle résidence et emplacement très calme , nous mettons en vente plusieurs appartements composés de deux à trois chambres de superficies de 83m2 à 126m2 avec ou sans terasse. avec double ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'oasis'},
#  {'link': 'https://www.mubawab.ma/fr/a/7700797/appartement-trois-chambres-avec-terrasse-%C3%A0-vendre',
#   'property_id': '7700797',
#   'price': 1900000.0,
#   'title': 'appartement trois chambres avec terrasse...',
#   'description': "dans une résidence propre et bien aménagée à côté du complexe sportif mohamed 5, nous mettons en vente cet appartement spacieux composé : - d'un grand salon donnant sur une terrasse de 13m2 - de trois ... En savoir plus",
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'maârif extension'},
#  {'link': 'https://www.mubawab.ma/fr/a/7685812/superbe-appartement-%C3%A0-vendre-%C3%A0-californie-superficie-72-m%C2%B2-ascenseur-et-terrasse',
#   'property_id': '7685812',
#   'price': 750000.0,
#   'title': 'superbe appartement à vendre à californie...',
#   'description': 'faites une belle affaire en achetant cet appartement. prix 750 000 dh. 1 salle de bains, superficie de 72 m². 1 pièces. 1 chambre à coucher. 3ème étage. moins de 20 ans. à rénover. revêtement: carrelage. ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'californie'},
#  {'link': 'https://www.mubawab.ma/fr/a/7708671/bel-appt-a-vendre',
#   'property_id': '7708671',
#   'price': 900000.0,
#   'title': 'bel appt a vendre',
#   'description': 'bel appt neuf a vendre ,sol en marbre et parquet.',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'sidi maarouf'},
#  {'link': 'https://www.mubawab.ma/fr/a/7708619/bel-appartement-%C3%A0-vendre-%C3%A0-sidi-othmane-2-pi%C3%A8ces-salon-traditionnel',
#   'property_id': '7708619',
#   'price': 250000.0,
#   'title': 'bel appartement à vendre à sidi othmane...',
#   'description': 'découvrez cet appartement à vendre. prix 250 000 dh. 2 pièces, 1 salle de bains, surface 50 m². 2 chambres à coucher. 4ème étage. moins de 30 ans. à rénover. type de sol: carrelage. confort et tradition ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'sidi othmane'},
#  {'link': 'https://www.mubawab.ma/fr/a/7677257/residence-alfirdaous',
#   'property_id': '7677257',
#   'price': 450000.0,
#   'title': 'residence alfirdaous',
#   'description': 'je mets en vente mon appartement en 3eme étage d une superficie de 54 m bien ensoleillé toute la journée, avec 2 chambres contenants des placard encastrés et un grand salon, cuisine avec balcon , à ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'oulfa'},
#  {'link': 'https://www.mubawab.ma/fr/a/7708608/appartement-en-vente-%C3%A0-sidi-othmane-2-pi%C3%A8ces-confortables-cuisine-bien-%C3%A9quip%C3%A9e',
#   'property_id': '7708608',
#   'price': 480000.0,
#   'title': 'appartement en vente à sidi othmane. 2 pi...',
#   'description': 'ne laissez pas passer cet appartement à vendre. prix 480 000 dh. 2 pièces, 1 salle de bains, superficie 80 m². 2 chambres à coucher. 2ème étage. moins de 30 ans. revêtement: carrelage. spacieux salon ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'sidi othmane'},
#  {'link': 'https://www.mubawab.ma/fr/a/7705025/appartement-54-m2',
#   'property_id': '7705025',
#   'price': 450000.0,
#   'title': 'appartement 54 m2',
#   'description': 'je mets en vente mon appartement en 3eme étage d une superficie de 54 m bien ensoleillé toute la journée, avec 2 chambres contenants des placard encastrés et un grand salon, cuisine avec balcon , à ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'oulfa'},
#  {'link': 'https://www.mubawab.ma/fr/a/7625405/gauthier-vente-appartement-terrasse',
#   'property_id': '7625405',
#   'price': 2500000.0,
#   'title': 'gauthier vente appartement terrasse',
#   'description': "gauthier-vente-appartement-terrasse. nous vous proposons à la vente bel appartement avec terrasse sur quartier gauthier d'une superficie de 120 m² a l'étage élevé, bien ensoleillé. il se compose de ... En savoir plus",
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'gauthier'},
#  {'link': 'https://www.mubawab.ma/fr/a/7708558/apt-hay-essalm-%C3%A0-cot%C3%A9-de-l-hopital-chaikh-khalifa',
#   'property_id': '7708558',
#   'price': 400000.0,
#   'title': "apt hay essalm à coté de l'hopital chaikh...",
#   'description': 'appartement à vendre - 4éme étages - rénové oulfa casablanca prés du quartier finance city et hôpital cheikh khalifa, 2 façades, compose de 1- salon 2- chambres 1- cuisine 1- salle à manger 1- ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'laymoune'},
#  {'link': 'https://www.mubawab.ma/fr/a/7669779/appartement-%C3%A0-vendre-au-maarif-extension',
#   'property_id': '7669779',
#   'price': 1450000.0,
#   'title': 'appartement à vendre au maarif extension',
#   'description': 'votre agent immobilier amina tahiri tel 0619205812 nb cet appartement est dans un bel immeuble et le pris très très intéressant excellence luxry at immo un appartement à la vente de deux chambres ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'maârif extension'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7596073/superbe-appartement-%C3%A0-vendre-%C3%A0-ahl-loghlam-hay-assalam-3-belles-chambres',
#   'property_id': '7596073',
#   'price': 250000.0,
#   'title': 'superbe appartement à vendre à ahl loghla...',
#   'description': 'c’est au cœur de la ville nouvelle de tit mellil, à 2mins seulement de l’autoroute périphérique et 20 mins seulement de l’aéroport mohamed v, que shems al madina vous fait découvrir sa nouvelle résidence « ... En savoir plus',
#   'rooms': 3.0,
#   'surface': 67.0,
#   'city': 'casablanca',
#   'district': 'ahl loghlam (hay assalam)'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7602661/appartement-158m2-%C3%A0-californie-royal-park',
#   'property_id': '7602661',
#   'price': 2885000.0,
#   'title': 'appartement 158m2 à californie royal park',
#   'description': 'enveloppé dans un écrin verdoyant, royal park vous offre la quintessence du luxe et un service raffiné dans une atmosphère zen. cet appartement de 158 m2, situé au 3 eme étage comprend 3 chambres ... En savoir plus',
#   'rooms': 3.0,
#   'surface': 158.0,
#   'city': 'casablanca',
#   'district': 'californie'},
#  {'link': 'https://www.mubawab.ma/fr/a/7688491/a-vendre-appartement-sur-la-ferme-bretonne',
#   'property_id': '7688491',
#   'price': 2600000.0,
#   'title': 'a vendre appartement sur la ferme bretonn...',
#   'description': 'splendide appartement à vendre sur la ferme bretonne environ 140 m², se compose de: -une réception ouverte sur balcon sans vis à vis -wc invités -cuisine équipée avec logia -deux chambres -salle ... En savoir plus',
#   'rooms': 3.0,
#   'surface': 140.0,
#   'city': 'casablanca',
#   'district': 'ferme bretonne (hay arraha)'},
#  {'link': 'https://www.mubawab.ma/fr/a/7679318/a-vendre-appartement-sur-gauthier',
#   'property_id': '7679318',
#   'price': 4800000.0,
#   'title': 'a vendre appartement sur gauthier',
#   'description': 'nouvelle annonce immobilière : superbe appartement à vendre sur gauthier ! - superficie de 380 m² dont 150 m² de terrasse - 4 chambres à coucher, - 3 salles de bain - 4 terrasses offrant une vue ... En savoir plus',
#   'rooms': 4.0,
#   'surface': 380.0,
#   'city': 'casablanca',
#   'district': 'gauthier'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7284458/apartement-de-77m%C2%B2-en-vente-r%C3%A9sidence-el-yassamine',
#   'property_id': '7284458',
#   'price': 845000.0,
#   'title': 'apartement de 77m² en vente, résidence el...',
#   'description': 'avec plus de 35 ans d’expérience, le groupe ikamati, réputé pour la qualité de ses matériaux de construction, vous présente votre chez-soi clé en main à la résidence el yassamine. la résidence de standing ... En savoir plus',
#   'rooms': 3.0,
#   'surface': 77.0,
#   'city': 'casablanca',
#   'district': 'bernoussi'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7461576/appartement-de-148m%C2%B2-en-vente-place-de-parking-titr%C3%A9e-de-16-m2-chraibi-immobilier',
#   'property_id': '7461576',
#   'price': 1660000.0,
#   'title': 'appartement de 148m² en vente place de pa...',
#   'description': 'chraibi immobilier est un projet résidentiel composé de six immeubles situé au cœur de casablanca dans le quartier belevedere-gironde. le projet repose sur un concept fort autour de trois éléments ... En savoir plus',
#   'rooms': 3.0,
#   'surface': 148.0,
#   'city': 'casablanca',
#   'district': 'la gironde'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7276877/apartement-de-72m%C2%B2-en-vente-r%C3%A9sidence-el-yassamine',
#   'property_id': '7276877',
#   'price': 670000.0,
#   'title': 'apartement de 72m² en vente, résidence el...',
#   'description': 'avec plus de 35 ans d’expérience, le groupe ikamati, réputé pour la qualité de ses matériaux de construction, vous présente votre chez-soi clé en main à la résidence el yassamine. la résidence de standing ... En savoir plus',
#   'rooms': 2.0,
#   'surface': 72.0,
#   'city': 'casablanca',
#   'district': 'bernoussi'},
#  {'link': 'https://www.mubawab.ma/fr/pa/7276879/apartement-de-75m%C2%B2-en-vente-r%C3%A9sidence-el-yassamine',
#   'property_id': '7276879',
#   'price': 700000.0,
#   'title': 'apartement de 75m² en vente, résidence el...',
#   'description': 'avec plus de 35 ans d’expérience, le groupe ikamati, réputé pour la qualité de ses matériaux de construction, vous présente votre chez-soi clé en main à la résidence el yassamine. la résidence de standing ... En savoir plus',
#   'rooms': 2.0,
#   'surface': 75.0,
#   'city': 'casablanca',
#   'district': 'bernoussi'},
#  {'link': 'https://www.mubawab.ma/fr/p/3274/r%C3%A9sidence-diaz',
#   'property_id': None,
#   'price': 1280000.0,
#   'title': None,
#   'description': 'idéal pour les investisseurs ou les jeunes actifs à la recherche d’une acquisition, la résidence diaz, est un projet qui concilie entre centre-ville et calme inouï. avant-gardisme et confort , définissent parfaitement la résidence fermée et sécurisée diaz. situé au ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'maârif extension'},
#  {'link': 'https://www.mubawab.ma/fr/a/7708495/appartement-%C3%A0-vendre-51m%C2%B2-fal-hana-ain-seb%C3%A2a-casa',
#   'property_id': '7708495',
#   'price': 590000.0,
#   'title': 'appartement à vendre 51m² fal hana ain se...',
#   'description': 'je mets en vente un appartement surface 51m² à ain sebâa casablanca 2émé étage dans une résidence fermée et sécurisée 24/7 à fal el hanaa, se compose de deux chambres avec parquet salon cuisine équipée ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'aïn sebaâ'},
#  {'link': 'https://www.mubawab.ma/fr/a/7565319/penthouse-neuf-jamais-habit%C3%A9-%C3%A0-la-vente-vue-mer-avec-terrqsse',
#   'property_id': '7565319',
#   'price': 11000000.0,
#   'title': 'penthouse neuf jamais habité à la vente v...',
#   'description': 'découvrez ce penthouse à vendre. prix 12 000 000 dh. 4 pièces, 3 salles de bains, surface 280 m². 3 chambres. 16ème étage. moins de 5 ans. type de sol: marbre. confort et sécurité avec chauffage central, ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'ain diab'},
#  {'link': 'https://www.mubawab.ma/fr/a/7708467/vend-appartement-%C3%A0-gauthier-superficie-60-m%C2%B2-bien-meubl%C3%A9-',
#   'property_id': '7708467',
#   'price': 1320000.0,
#   'title': 'vend appartement à gauthier. superficie 6...',
#   'description': 'ne laissez pas passer cet appartement à vendre. prix 1 320 000 dh. 3 pièces, 1 salle de bains, superficie 60 m². 1 chambre. 1er étage. moins de 5 ans. revêtement: marbre. meublé. cet appartement est en ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'gauthier'},
#  {'link': 'https://www.mubawab.ma/fr/a/7250704/joli-appartement-gauthier-place-olier',
#   'property_id': '7250704',
#   'price': 3000000.0,
#   'title': 'joli appartement gauthier place olier',
#   'description': 'elfy immobilier vous propose a la vente un bel appartement de 248 m2 dont 20 m2 de terrasse, dans un bel immeuble tres bien entretenu a gauthier place olier. se compse de 3 coins salon avec cheminée, 3 ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'gauthier'},
#  {'link': 'https://www.mubawab.ma/fr/a/7708423/appartement-%C3%A0-vendre-roches-noires',
#   'property_id': '7708423',
#   'price': 950000.0,
#   'title': 'appartement à vendre roches noires',
#   'description': 'je mets en vente un appartement de 99m à roches noires vec un prix intéressant, composé de 2 chambres double salon, 2 sdb et cuisine équipée plus place au garage. très bien ensoleillé et récemment rénové ... En savoir plus',
#   'rooms': nan,
#   'surface': nan,
#   'city': 'casablanca',
#   'district': 'roches noires'},
#  ...]

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=400,
    chunk_overlap=20,
    length_function=len,
    separators=["\n\n", "\n", " ", ""]
)

# %%
text_splitter.split_text(data_dict[0]["description"])[:2]
# Out:
# ['c’est au cœur de la ville nouvelle de tit mellil, à 2mins seulement de l’autoroute périphérique et 20mins seulement de l’aéroport mohamed v, que shem’s al madina vous fait découvrir sa nouvelle résidence « ... En savoir plus']

# %%
from langchain.document_loaders import DirectoryLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings.openai import OpenAIEmbeddings
import pinecone 
from langchain.vectorstores import Pinecone
from langchain import OpenAI
from langchain.chains import RetrievalQA
import json
import glob
import os
import random

# %%
json_files = glob.glob('data/*.json')

data = []

for file in json_files:
    with open(file, 'r', encoding='utf-8') as f:
        for line in f:
            data.append(json.loads(line))

data = [{'price': e['price'],
         'title': e['title'],
         'size_and_rooms': e['size_and_rooms'],
         'location': e['location'],
         'description': e['description'],
         
    } for e in data]

for i in range(len(data)):
    data[i]['price'] = data[i]['price'].replace('\xa0', ' ')
    for e in ['title', 'size_and_rooms', 'location', 'description']:
        try:
            data[i][e] = data[i][e].encode('latin1').decode('utf8')
        except: pass

#data = [' '.join([f'"{key}": {e[key]};' for key in e.keys()]) for e in data]

def str_transfrom(s):
    if s is None:
        return ''
    return s

data = ["Situé à " + str_transfrom(e["location"]) + " . Ce bien est affiché au prix de " + str_transfrom(e["price"]) + " . Voici la description détaillé du bien: " + str_transfrom(e["description"]) for e in data]

# %%
PINECONE_API_KEY =  "c67c45bc-0478-498b-a411-36a6207a750a"
PINECONE_ENV = "us-west4-gcp-free"
OPENAI_API_KEY = "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"

os.environ['OPENAI_API_KEY'] = OPENAI_API_KEY
os.environ['PINECONE_API_KEY'] = PINECONE_API_KEY

# %%
pinecone.init(
    api_key=PINECONE_API_KEY,
    environment=PINECONE_ENV
)
embeddings = OpenAIEmbeddings()
data_db = Pinecone.from_texts(
    data, 
    embeddings, 
    index_name='langchain-bot'
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 6
#       1 pinecone.init(
#       2     api_key=PINECONE_API_KEY,
#       3     environment=PINECONE_ENV
#       4 )
#       5 embeddings = OpenAIEmbeddings()
# ----> 6 data_db = Pinecone.from_texts(
#       7     data,
#       8     embeddings,
#       9     index_name='langchain-bot'
#      10 )
#
# File c:\Users\ACER\PycharmProjects\immo-ai-service\venv\lib\site-packages\langchain\vectorstores\pinecone.py:232, in Pinecone.from_texts(cls, texts, embedding, metadatas, ids, batch_size, text_key, index_name, namespace, **kwargs)
#     230     ids_batch = [str(uuid.uuid4()) for n in range(i, i_end)]
#     231 # create embeddings
# --> 232 embeds = embedding.embed_documents(lines_batch)
#     233 # prep metadata and upsert batch
#     234 if metadatas:
#
# File c:\Users\ACER\PycharmProjects\immo-ai-service\venv\lib\site-packages\langchain\embeddings\openai.py:297, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size)
#     285 """Call out to OpenAI's embedding endpoint for embedding search docs.
#     286
#     287 Args:
#    (...)
#     293     List of embeddings, one for each text.
#     294 """
#     295 # NOTE: to keep things simple, we assume the list may contain texts longer
#     296 #       than the maximum context and use length-safe embedding function.
# --> 297 return self._get_len_safe_embeddings(texts, engine=self.deployment)
#
# File c:\Users\ACER\PycharmProjects\immo-ai-service\venv\lib\site-packages\langchain\embeddings\openai.py:233, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size)
#     231 _chunk_size = chunk_size or self.chunk_size
#     232 for i in range(0, len(tokens), _chunk_size):
# --> 233     response = embed_with_retry(
#     234         self,
#     235         input=tokens[i : i + _chunk_size],
#     236         engine=self.deployment,
#     237         request_timeout=self.request_timeout,
#     238         headers=self.headers,
#     239     )
#     240     batched_embeddings += [r["embedding"] for r in response["data"]]
#     242 results: List[List[List[float]]] = [[] for _ in range(len(texts))]
#
# File c:\Users\ACER\PycharmProjects\immo-ai-service\venv\lib\site-packages\langchain\embeddings\openai.py:64, in embed_with_retry(embeddings, **kwargs)
#      60 @retry_decorator
#      61 def _embed_with_retry(**kwargs: Any) -> Any:
#      62     return embeddings.client.create(**kwargs)
# ---> 64 return _embed_with_retry(**kwargs)
#
# File c:\Users\ACER\PycharmProjects\immo-ai-service\venv\lib\site-packages\tenacity\__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File c:\Users\ACER\PycharmProjects\immo-ai-service\venv\lib\site-packages\tenacity\__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     377 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#     381         try:
#
# File c:\Users\ACER\PycharmProjects\immo-ai-service\venv\lib\site-packages\tenacity\__init__.py:314, in BaseRetrying.iter(self, retry_state)
#     312 is_explicit_retry = fut.failed and isinstance(fut.exception(), TryAgain)
#     313 if not (is_explicit_retry or self.retry(retry_state)):
# --> 314     return fut.result()
#     316 if self.after is not None:
#     317     self.after(retry_state)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\concurrent\futures\_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\concurrent\futures\_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File c:\Users\ACER\PycharmProjects\immo-ai-service\venv\lib\site-packages\tenacity\__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     380 if isinstance(do, DoAttempt):
#     381     try:
# --> 382         result = fn(*args, **kwargs)
#     383     except BaseException:  # noqa: B902
#     384         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File c:\Users\ACER\PycharmProjects\immo-ai-service\venv\lib\site-packages\langchain\embeddings\openai.py:62, in embed_with_retry.<locals>._embed_with_retry(**kwargs)
#      60 @retry_decorator
#      61 def _embed_with_retry(**kwargs: Any) -> Any:
# ---> 62     return embeddings.client.create(**kwargs)
#
# File c:\Users\ACER\PycharmProjects\immo-ai-service\venv\lib\site-packages\openai\api_resources\embedding.py:33, in Embedding.create(cls, *args, **kwargs)
#      31 while True:
#      32     try:
# ---> 33         response = super().create(*args, **kwargs)
#      35         # If a user specifies base64, we'll just return the encoded string.
#      36         # This is only for the default case.
#      37         if not user_provided_encoding_format:
#
# File c:\Users\ACER\PycharmProjects\immo-ai-service\venv\lib\site-packages\openai\api_resources\abstract\engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File c:\Users\ACER\PycharmProjects\immo-ai-service\venv\lib\site-packages\openai\api_requestor.py:220, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     209 def request(
#     210     self,
#     211     method,
#    (...)
#     218     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     219 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
# --> 220     result = self.request_raw(
#     221         method.lower(),
#     222         url,
#     223         params=params,
#     224         supplied_headers=headers,
#     225         files=files,
#     226         stream=stream,
#     227         request_id=request_id,
#     228         request_timeout=request_timeout,
#     229     )
#     230     resp, got_stream = self._interpret_response(result, stream)
#     231     return resp, got_stream, self.api_key
#
# File c:\Users\ACER\PycharmProjects\immo-ai-service\venv\lib\site-packages\openai\api_requestor.py:520, in APIRequestor.request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     518     _thread_context.session = _make_session()
#     519 try:
# --> 520     result = _thread_context.session.request(
#     521         method,
#     522         abs_url,
#     523         headers=headers,
#     524         data=data,
#     525         files=files,
#     526         stream=stream,
#     527         timeout=request_timeout if request_timeout else TIMEOUT_SECS,
#     528         proxies=_thread_context.session.proxies,
#     529     )
#     530 except requests.exceptions.Timeout as e:
#     531     raise error.Timeout("Request timed out: {}".format(e)) from e
#
# File c:\Users\ACER\PycharmProjects\immo-ai-service\venv\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\ACER\PycharmProjects\immo-ai-service\venv\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\ACER\PycharmProjects\immo-ai-service\venv\lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\ACER\PycharmProjects\immo-ai-service\venv\lib\site-packages\urllib3\connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File c:\Users\ACER\PycharmProjects\immo-ai-service\venv\lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\ACER\PycharmProjects\immo-ai-service\venv\lib\site-packages\urllib3\connection.py:454, in HTTPConnection.getresponse(self)
#     451 from .response import HTTPResponse
#     453 # Get the response from http.client.HTTPConnection
# --> 454 httplib_response = super().getresponse()
#     456 try:
#     457     assert_header_parsing(httplib_response.msg)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.10_3.10.3056.0_x64__qbz5n2kfra8p0\lib\ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
index = pinecone.Index("langchain-bot")

# %%
type(data_db)
# Out:
# langchain.vectorstores.pinecone.Pinecone

# %%
query = "un appartement de 60m2 avec un prix qui ne dépasse pas 1200000DH avec un bacon"
search_docs = data_db.similarity_search(query)
search_docs
# Out:
# [Document(page_content='Situé à Mandarona à Casablanca . Ce bien est affiché au prix de 600 000 DH . Voici la description détaillé du bien: ne laissez pas passer cet appartement à vendre. prix 620 000 dh. 2 chambres, 1 salle de bains, 60 m². 1 pièces. 4ème étage. moins de 20 ans. revêtement: carrelage. sécurité maximale avec porte blindée. ... En savoir plus', metadata={}),
#  Document(page_content="Situé à Mandarona à Casablanca . Ce bien est affiché au prix de 680 000 DH . Voici la description détaillé du bien: faites une belle affaire en achetant cet appartement. prix 680 000 dh. 5 pièces, 2 chambres, 1 salle de bains, 60 m². 2ème étage. moins de 20 ans. type de sol: parquet. porte d'entrée blindée. le bien ... En savoir plus", metadata={}),
#  Document(page_content='Situé à Mandarona à Casablanca . Ce bien est affiché au prix de 600 000 DH . Voici la description détaillé du bien: affaire à saisir pour cet appartement à vendre. prix 620 000 dh. 2 chambres, 1 salle de bains, surface 60 m². 1 pièces. 4ème étage. moins de 20 ans. revêtement: carrelage. bien meublé. cet appartement ... En savoir plus', metadata={}),
#  Document(page_content="Situé à Mandarona à Casablanca . Ce bien est affiché au prix de 1 200 000 DH . Voici la description détaillé du bien: appartement idéal à la vente. prix 1 200 000 dh. 5 pièces dont 3 chambres, 1 salle de bains, 110 m². 3ème étage. moins de 20 ans. antenne parabolique. le bien dispose également d'un beau salon marocain ... En savoir plus", metadata={})]

# %%
for it in search_docs:
    print(it.page_content)
    break
# Out:
# Appartement 62m2 à vendre Mandaronna Situé à Ain Chock à Casablanca . Ce bien est affiché au prix de 620 000 DH . Voici la description détaillé du bien: je mets en vente un appartement avec une superficie de 62m2, quatrième étage. elle comporte un salon, un séjour, deux chambres à coucher ( une avec un petit balcon), une douche, une cuisine et un grand ... En savoir plus

# %%
from langchain.chat_models import ChatOpenAI
llm = ChatOpenAI()

qa = RetrievalQA.from_chain_type(
    llm=llm, 
    chain_type='stuff',
    retriever=data_db.as_retriever(),
)
# Out:
# "Le prix moyen des appartements à Casa dépend de plusieurs facteurs tels que l'emplacement, la taille, le niveau de standing, etc. Les exemples de biens immobiliers que vous avez fournis ont des prix allant de 8 500 DH à 950 000 DH. Il est donc difficile de donner une réponse précise sur le prix moyen sans plus de détails."

# %%
from langchain.schema import (
    AIMessage,
    HumanMessage,
    SystemMessage
)

# %%
query = "quel le prix moyen à Casa ?"
result = qa.run(query)

result
# Out:
# "Le prix moyen à Casa dépend du type d'appartement et de son emplacement. Les différents biens immobiliers mentionnés dans les descriptions ont des prix différents. Par exemple, le premier appartement n'a pas de prix affiché et le prix de l'appartement à Casa Finance City est de 8 500 DH, tandis que l'appartement à Hay Hassani est affiché à 950 000 DH. Le deuxième appartement est affiché à 430 000 DH."

# %%
query = "Quel le prix moyen à casa ?"
content = f"Est ce que question demande un calcul: {query} \n Répondre exactement par oui ou non"
llm([HumanMessage(content=content)])
# Out:
# AIMessage(content='Non.', additional_kwargs={}, example=False)

# %%
from langchain.memory import ConversationBufferMemory

memory = ConversationBufferMemory(memory_key="chat_history")

# %%
from langchain.agents import load_tools

tools = load_tools(
    ["llm-math"], 
    llm=llm
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 from langchain.agents import load_tools
#       3 tools = load_tools(
#       4     ["llm-math"],
# ----> 5     llm=llm
#       6 )
#
# NameError: name 'llm' is not defined
